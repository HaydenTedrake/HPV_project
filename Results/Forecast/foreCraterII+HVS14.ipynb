# %%
import astropy.units as u
import astropy.coordinates as coord
import matplotlib.pyplot as plt
import numpy as np
import gala.dynamics as gd
import gala.potential as gp
import matplotlib.cm as cm
import matplotlib.gridspec as gridspec
from scipy.optimize import minimize_scalar
from matplotlib.patches import Ellipse
from scipy.spatial.distance import mahalanobis
from scipy.stats import chi2

# %% [markdown]
# Helper Functions

# %%
def sample(dict, ics, n_samples=100):
    ra_samples = np.random.normal(dict['ra'], dict['e_ra'], n_samples)
    dec_samples = np.random.normal(dict['dec'], dict['e_dec'], n_samples)
    dist_samples = np.random.normal(dict['dist'], dict['e_dist'], n_samples)
    rv_samples = np.random.normal(dict['rv'], dict['e_rv'], n_samples)

    pmra_central = np.random.normal(dict['pmra'], dict['e_pmra'], 1)
    pmdec_central = np.random.normal(dict['pmdec'], dict['e_pmdec'], 1)
    pmra_samples = np.random.normal(pmra_central, dict['e_pmra']/4, n_samples)
    pmdec_samples = np.random.normal(pmdec_central, dict['e_pmdec']/4, n_samples)

    ics_list = []
    ics_list.append(ics)
    for ra, dec, dist, pmra, pmdec, rv in zip(ra_samples, dec_samples, dist_samples, pmra_samples, pmdec_samples, rv_samples):
        sc = coord.SkyCoord(ra=ra * u.degree,
                    dec=dec * u.degree,
                    distance=dist * u.kpc,
                    pm_ra_cosdec=pmra * (u.mas / u.yr),
                    pm_dec=pmdec * (u.mas / u.yr),
                    radial_velocity=rv * (u.km / u.s),
                    frame="icrs")
        gc = sc.transform_to(coord.Galactocentric)
        ics = gd.PhaseSpacePosition(pos=gc.cartesian.xyz, vel=gc.velocity.d_xyz)
        ics_list.append(ics)
    
    return ics_list

def calculate_orbits(dict, ics, num_steps):
    ics_list = sample(dict, ics)

    orbits = []
    for ics in ics_list:
        orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=num_steps)
        orbits.append(orbit)

    return orbits

def plot_ellipse(x_vals, y_vals, plane="XY"):
    pos = np.column_stack((x_vals, y_vals))
    mean = np.mean(pos, axis=0)
    cov = np.cov(pos, rowvar=False)

    eigvals, eigvecs = np.linalg.eigh(cov)
    order = eigvals.argsort()[::-1]
    eigvals, eigvecs = eigvals[order], eigvecs[:, order]

    angle = np.degrees(np.arctan2(*eigvecs[:, 0][::-1]))

    fig, ax = plt.subplots(figsize=(4, 3))
    ax.scatter(x_vals, y_vals, s=3, color='red', alpha=0.5)

    # Confidence levels: 1σ (68%), 2σ (95%), 3σ (99.7%)
    for nsig in [1, 2, 3]:
        width, height = 2 * nsig * np.sqrt(eigvals)
        ellipse = Ellipse(xy=mean, width=width, height=height, angle=angle,
                          edgecolor='blue', fc='None', lw=2, label=f"{nsig}σ")
        ax.add_patch(ellipse)

    ax.set_xlabel(f"{plane[0]} [kpc]")
    ax.set_ylabel(f"{plane[1]} [kpc]")
    ax.grid(True)
    plt.tight_layout()
    plt.xlim(-40, 40)
    plt.ylim(-120, -20)
    plt.savefig('foreCraterII.png')
    plt.show()

def distance_mw(num_steps, ics):
    orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=num_steps)
    final_z = orbit[-1].pos.xyz.to(u.kpc).value[2]
    return abs(final_z)

def plot_closest(dict, ics, function, mw=False, target=[0,0,0]):
    ics_list = sample(dict, ics)

    k=3

    points = []
    times = []
    for ics in ics_list:
        result = minimize_scalar(
            function,
            args=(ics,),
            bounds=(0, 8000),  # search between 0 and 8000 steps (800 Myr)
            method='bounded'
        )
        orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=int(result.x))
        times.append(int(result.x)*0.1)
        final_pos = orbit[-1].pos.xyz.to(u.kpc).value[:k]
        points.append(final_pos)

    points = np.array(points)

    # if mw==True:
    #     x = points[:, 0]
    #     y = points[:, 1]

    #     plot_ellipse(x, y)
    # else:
    #     x = points[:, 0]
    #     y = points[:, 1]
    #     z = points[:, 2]

    #     plot_ellipse(x, y, "XY")
    #     # plot_ellipse(x, z, "XZ")
    #     # plot_ellipse(y, z, "YZ")

    # mahalanobis distance
    target = np.array(target)
    mean = np.mean(points, axis=0)
    cov = np.cov(points, rowvar=False)
    inv_cov = np.linalg.inv(cov)

    mahal_dist = mahalanobis(target, mean, inv_cov)
    
    p_value = 1 - chi2.cdf(mahal_dist**2, df=k)

    return p_value, times

# %% [markdown]
# First, define a gravitational potential.

# %%
pot = gp.MilkyWayPotential()

# %% [markdown]
# Crater II

# %%
dwarf_dict = {
    'ra': 177.310, #degree
    'e_ra': 0.03, #degree
    'dec': -18.413, #degree
    'e_dec': 0.03, #degree
    'dist': 117.5, #kpc
    'e_dist': 1.1, #kpc
    'pmra': -0.07, #mas/yr
    'e_pmra': 0.02, #mas/yr
    'pmdec': -0.11, #mas/yr
    'e_pmdec': 0.01, #mas/yr
    'rv': 87.5, #km/s
    'e_rv': 0.4, #km/s
    }
dwarf = coord.SkyCoord(
    ra=dwarf_dict['ra'] * u.degree,
    dec=dwarf_dict['dec'] * u.degree,
    distance=dwarf_dict['dist'] * u.kpc,
    pm_ra_cosdec=dwarf_dict['pmra'] * (u.mas / u.yr),
    pm_dec=dwarf_dict['pmdec'] * (u.mas / u.yr),
    radial_velocity=dwarf_dict['rv'] * (u.km / u.s),
    frame="icrs"
)
dwarf_GC = dwarf.transform_to(coord.Galactocentric)
dwarf_ics = gd.PhaseSpacePosition(pos=dwarf_GC.cartesian.xyz, vel=dwarf_GC.velocity.d_xyz)
# Out:
# WARNING: AstropyDeprecationWarning: The get_name method is deprecated and may be removed in a future version.
#         Use name instead. [gala.dynamics.core]

# %% [markdown]
# HVS 14

# %%
dict14 = {
    'ra': 161.0072805184, #degree
    'e_ra': 0.0001, #degree
    'dec': 6.1941762509, #degree
    'e_dec': 0.0001, #degree
    'dist': 102.66, #kpc
    'e_dist': 16.55, #kpc
    'pmra': -2.17, #mas/yr
    'e_pmra': 1.38, #mas/yr
    'pmdec': 2.28, #mas/yr
    'e_pmdec': 1.68, #mas/yr
    'rv': 537.30, #km/s
    'e_rv': 7.20, #km/s
    }
hvs14 = coord.SkyCoord(
    ra=dict14['ra'] * u.degree,
    dec=dict14['dec'] * u.degree,
    distance=dict14['dist'] * u.kpc,
    pm_ra_cosdec=dict14['pmra'] * (u.mas / u.yr),
    pm_dec=dict14['pmdec'] * (u.mas / u.yr),
    radial_velocity=dict14['rv'] * (u.km / u.s),
    frame="icrs"
)
hvs14_GC = hvs14.transform_to(coord.Galactocentric)
hvs14_ics = gd.PhaseSpacePosition(pos=hvs14_GC.cartesian.xyz, vel=hvs14_GC.velocity.d_xyz)

# %% [markdown]
# Milky Way Plot (z=0)

# %%
count = 0
for _ in range(1000):
    p_value, times = plot_closest(dict14, hvs14_ics, distance_mw, mw=True)
    # print(f"p_value: {p_value}")
    if p_value < 0.05:
        count += 1
print(f"count: {count}")
# Out:
# count: 658

# %% [markdown]
# Milky Way f_mc Plot

# %%
factor = [2, 4]
f_mc = [0.486, 0.658]

# %% [markdown]
# Galaxy Plot

# %%
min14 = 366.5427377870987

dwarf_orbits = calculate_orbits(dwarf_dict, dwarf_ics, min14)
points = []
for orbit in dwarf_orbits:
    final_pos = orbit[-1].pos.xyz.to(u.kpc).value[:3]
    points.append(final_pos)
points = np.array(points)
mean = np.mean(points, axis=0)

# print(f"mean: {mean}")

def distance_dwarf(num_steps, ics):
    orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=num_steps)
    final_pos = orbit[-1].pos.xyz.to(u.kpc).value[:3]
    distance = np.linalg.norm(final_pos - mean)
    return distance

for _ in range(1000):
    p_value, times = plot_closest(dict14, hvs14_ics, distance_dwarf, target=mean)
    # print(f"p_value: {p_value}")
    if p_value < 0.05:
        count += 1
print(f"count: {count}")

# # Plot histogram
# plt.hist(times, bins=10, edgecolor='black')
# plt.xlabel('Time (Myr)')
# plt.ylabel('Frequency')
# plt.title('Histogram of Times')
# plt.grid(True)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:749, in UnitBase.to_string(self, format, **kwargs)
#     748 try:
# --> 749     return get_format(format).to_string(self, **kwargs)
#     750 except (TypeError, ValueError) as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/format/__init__.py:85, in get_format(format)
#      84     except KeyError:
# ---> 85         raise ValueError(f"Unknown format {format!r}.") from None
#      86 if isinstance(format, type) and issubclass(format, Base):
#
# ValueError: Unknown format ''.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 20
#      17     return distance
#      19 for _ in range(1000):
# ---> 20     p_value, times = plot_closest(dict14, hvs14_ics, distance_dwarf, target=mean)
#      21     # print(f"p_value: {p_value}")
#      22     if p_value < 0.05:
#
# Cell In[2], line 81, in plot_closest(dict, ics, function, mw, target)
#      79 times = []
#      80 for ics in ics_list:
# ---> 81     result = minimize_scalar(
#      82         function,
#      83         args=(ics,),
#      84         bounds=(0, 8000),  # search between 0 and 8000 steps (800 Myr)
#      85         method='bounded'
#      86     )
#      87     orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=int(result.x))
#      88     times.append(int(result.x)*0.1)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_minimize.py:1027, in minimize_scalar(fun, bracket, bounds, args, method, tol, options)
#    1024     if bounds is None:
#    1025         raise ValueError('The `bounds` parameter is mandatory for '
#    1026                          'method `bounded`.')
# -> 1027     res = _minimize_scalar_bounded(fun, bounds, args, **options)
#    1028 elif meth == 'golden':
#    1029     res = _recover_from_bracket_error(_minimize_scalar_golden,
#    1030                                       fun, bracket, args, **options)
#
# File /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2389, in _minimize_scalar_bounded(func, bounds, args, xatol, maxiter, disp, **unknown_options)
#    2387 si = np.sign(rat) + (rat == 0)
#    2388 x = xf + si * np.maximum(np.abs(rat), tol1)
# -> 2389 fu = func(x, *args)
#    2390 num += 1
#    2391 fmin_data = (num, x, fu)
#
# Cell In[8], line 14, in distance_dwarf(num_steps, ics)
#      13 def distance_dwarf(num_steps, ics):
# ---> 14     orbit = pot.integrate_orbit(ics, dt=-0.1*u.Myr, n_steps=num_steps)
#      15     final_pos = orbit[-1].pos.xyz.to(u.kpc).value[:3]
#      16     distance = np.linalg.norm(final_pos - mean)
#
# File /opt/anaconda3/lib/python3.12/site-packages/gala/potential/potential/core.py:813, in PotentialBase.integrate_orbit(self, *args, **kwargs)
#     780 """
#     781 Integrate an orbit in the current potential using the integrator class
#     782 provided. Uses same time specification as `Integrator()` -- see
#    (...)
#     809
#     810 """
#     811 from ..hamiltonian import Hamiltonian
# --> 813 return Hamiltonian(self).integrate_orbit(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/gala/potential/hamiltonian/chamiltonian.pyx:319, in gala.potential.hamiltonian.chamiltonian.Hamiltonian.integrate_orbit()
#
# File /opt/anaconda3/lib/python3.12/site-packages/gala/integrate/timespec.py:34, in parse_time_specification(units, dt, n_steps, t1, t2, t)
#      31     n_steps = int(n_steps)
#      33 if hasattr(dt, "unit"):
# ---> 34     dt = dt.decompose(units).value
#      36 if hasattr(t1, "unit"):
#      37     t1 = t1.decompose(units).value
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/quantity.py:1617, in Quantity.decompose(self, bases)
#    1597 def decompose(self, bases: Collection[UnitBase] = ()) -> Self:
#    1598     """
#    1599     Generates a new `Quantity` with the units
#    1600     decomposed. Decomposed units have only irreducible units in
#    (...)
#    1615         A new object equal to this quantity with units decomposed.
#    1616     """
# -> 1617     return self._decompose(False, bases=bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/quantity.py:1647, in Quantity._decompose(self, allowscaledunits, bases)
#    1619 def _decompose(
#    1620     self, allowscaledunits: bool = False, bases: Collection[UnitBase] = ()
#    1621 ) -> Self:
#    1622     """
#    1623     Generates a new `Quantity` with the units decomposed. Decomposed
#    1624     units have only irreducible units in them (see
#    (...)
#    1645
#    1646     """
# -> 1647     new_unit = self.unit.decompose(bases=bases)
#    1649     # Be careful here because self.value usually is a view of self;
#    1650     # be sure that the original value is not being modified.
#    1651     if not allowscaledunits and hasattr(new_unit, "scale"):
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2220, in Unit.decompose(self, bases)
#    2219 def decompose(self, bases: Collection[UnitBase] = ()) -> UnitBase:
# -> 2220     return self._represents.decompose(bases=bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2437, in CompositeUnit.decompose(self, bases)
#    2434         self._decomposed_cache = self
#    2435     return self
# -> 2437 x = CompositeUnit(
#    2438     self.scale, self.bases, self.powers, decompose=True, decompose_bases=bases
#    2439 )
#    2440 if len(bases) == 0:
#    2441     self._decomposed_cache = x
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2351, in CompositeUnit.__init__(self, scale, bases, powers, decompose, decompose_bases, _error_check)
#    2349 self._bases = bases
#    2350 self._powers = powers
# -> 2351 self._expand_and_gather(decompose=decompose, bases=decompose_bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2403, in CompositeUnit._expand_and_gather(self, decompose, bases)
#    2401 for b, p in zip(self._bases, self._powers):
#    2402     if decompose and b not in bases:
# -> 2403         b = b.decompose(bases=bases)
#    2405     if isinstance(b, CompositeUnit):
#    2406         scale *= b._scale**p
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2220, in Unit.decompose(self, bases)
#    2219 def decompose(self, bases: Collection[UnitBase] = ()) -> UnitBase:
# -> 2220     return self._represents.decompose(bases=bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2437, in CompositeUnit.decompose(self, bases)
#    2434         self._decomposed_cache = self
#    2435     return self
# -> 2437 x = CompositeUnit(
#    2438     self.scale, self.bases, self.powers, decompose=True, decompose_bases=bases
#    2439 )
#    2440 if len(bases) == 0:
#    2441     self._decomposed_cache = x
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2351, in CompositeUnit.__init__(self, scale, bases, powers, decompose, decompose_bases, _error_check)
#    2349 self._bases = bases
#    2350 self._powers = powers
# -> 2351 self._expand_and_gather(decompose=decompose, bases=decompose_bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2403, in CompositeUnit._expand_and_gather(self, decompose, bases)
#    2401 for b, p in zip(self._bases, self._powers):
#    2402     if decompose and b not in bases:
# -> 2403         b = b.decompose(bases=bases)
#    2405     if isinstance(b, CompositeUnit):
#    2406         scale *= b._scale**p
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2220, in Unit.decompose(self, bases)
#    2219 def decompose(self, bases: Collection[UnitBase] = ()) -> UnitBase:
# -> 2220     return self._represents.decompose(bases=bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2437, in CompositeUnit.decompose(self, bases)
#    2434         self._decomposed_cache = self
#    2435     return self
# -> 2437 x = CompositeUnit(
#    2438     self.scale, self.bases, self.powers, decompose=True, decompose_bases=bases
#    2439 )
#    2440 if len(bases) == 0:
#    2441     self._decomposed_cache = x
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2351, in CompositeUnit.__init__(self, scale, bases, powers, decompose, decompose_bases, _error_check)
#    2349 self._bases = bases
#    2350 self._powers = powers
# -> 2351 self._expand_and_gather(decompose=decompose, bases=decompose_bases)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:2402, in CompositeUnit._expand_and_gather(self, decompose, bases)
#    2399 scale = self._scale
#    2401 for b, p in zip(self._bases, self._powers):
# -> 2402     if decompose and b not in bases:
#    2403         b = b.decompose(bases=bases)
#    2405     if isinstance(b, CompositeUnit):
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:942, in UnitBase.__eq__(self, other)
#     939     return NotImplemented
#     941 try:
# --> 942     return is_effectively_unity(self._to(other))
#     943 except UnitsError:
#     944     return False
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:1172, in UnitBase._to(self, other)
#    1164     if self_decomposed.powers == other_decomposed.powers and all(
#    1165         self_base is other_base
#    1166         for (self_base, other_base) in zip(
#    1167             self_decomposed.bases, other_decomposed.bases
#    1168         )
#    1169     ):
#    1170         return self_decomposed.scale / other_decomposed.scale
# -> 1172 raise UnitConversionError(f"'{self!r}' is not a scaled version of '{other!r}'")
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:675, in UnitBase.__repr__(self)
#     674 def __repr__(self) -> str:
# --> 675     return f'Unit("{self}")'
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:758, in UnitBase.__format__(self, format_spec)
#     756 def __format__(self, format_spec: str) -> str:
#     757     try:
# --> 758         return self.to_string(format=format_spec)
#     759     except ValueError:
#     760         return format(str(self), format_spec)
#
# File /opt/anaconda3/lib/python3.12/site-packages/astropy/units/core.py:751, in UnitBase.to_string(self, format, **kwargs)
#     749     return get_format(format).to_string(self, **kwargs)
#     750 except (TypeError, ValueError) as err:
# --> 751     from .format import known_formats
#     753     err.add_note(known_formats())
#     754     raise err
#
# File <frozen importlib._bootstrap>:1390, in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:
